# %% [markdown]
# # Semantic Segmentation, Deep Features visualization and binarization

# %%
import os
from segmentation import DeepLabModel, ColorMap, SemanticSegmentation

# %% [markdown]
# # Run the model for every image in the images folder.

# %%
images = [f for f in os.listdir('./images/')
          if os.path.splitext(f)[-1] == '.jpg']  # collect all images from images folder

# run model for every image
MODEL = SemanticSegmentation()
for image_name in images:
    MODEL.run_segmentation_visualization('./images/' + image_name)
# Out:
# loading model...
# model loaded successfully!
# running deeplab on image ./images/cats_and_plant.jpg...
# (384, 513, 3)
# running deeplab with aspp0/Conv2D:0 as output on ./images/cats_and_plant.jpg...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# running deeplab on image ./images/motorbike.jpg...
# (513, 384, 3)
# running deeplab with aspp0/Conv2D:0 as output on ./images/motorbike.jpg...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# running deeplab on image ./images/owl.jpg...
# (293, 513, 3)
# running deeplab with aspp0/Conv2D:0 as output on ./images/owl.jpg...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# running deeplab on image ./images/mustang.jpg...
# (384, 513, 3)
# running deeplab with aspp0/Conv2D:0 as output on ./images/mustang.jpg...
# ...
